# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import urllib3
import regex
from datetime import date
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
Andre = ["Data Engineer", "Data Warehouse", "Datawarehouse", "DWH", "Data Vault", "Talend", "Salesforce", "DataStage", "WhereScape", "PostgrSQL"]
